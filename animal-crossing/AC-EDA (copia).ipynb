# %%
import numpy as np
import pandas as pd
import datetime as dt

import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns

from statsmodels.tools.tools import add_constant
from statsmodels.stats.outliers_influence import variance_inflation_factor

from scipy import stats
import math
from scipy.stats import levene
import researchpy as rp
from sklearn.preprocessing import StandardScaler
import itertools

import statsmodels.api as sm
from statsmodels.formula.api import ols

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (10,8)

# %%
df_vecinos = pd.read_csv('datos/villagers.csv')
df_vecinos.head()
# Out:
#       Name                                    Icon Image  \
# 0  Admiral  https://acnhcdn.com/latest/NpcIcon/brd06.png
# 1  Agent S  https://acnhcdn.com/latest/NpcIcon/squ05.png
# 2    Agnes  https://acnhcdn.com/latest/NpcIcon/pig17.png
# 3       Al  https://acnhcdn.com/latest/NpcIcon/gor08.png
# 4  Alfonso  https://acnhcdn.com/latest/NpcIcon/crd00.png
#
#                                          Photo Image  \
# 0  https://acnhcdn.com/latest/NpcBromide/NpcNmlBr...
# 1  https://acnhcdn.com/latest/NpcBromide/NpcNmlSq...
# 2  https://acnhcdn.com/latest/NpcBromide/NpcNmlPi...
# 3  https://acnhcdn.com/latest/NpcBromide/NpcNmlGo...
# 4  https://acnhcdn.com/latest/NpcBromide/NpcNmlCr...
#
#                                          House Image    Species  Gender  \
# 0  https://acnhcdn.com/drivesync/render/houses/br...       Bird    Male
# 1  https://acnhcdn.com/drivesync/render/houses/sq...   Squirrel  Female
# 2  https://acnhcdn.com/drivesync/render/houses/pi...        Pig  Female
# ...

# %%
len(df_vecinos['Species'].unique())
# Out:
# 35

# %%
categoricas_vecinos = df_vecinos.select_dtypes(include='object')
categoricas_vecinos
# Out:
#          Name                                    Icon Image  \
# 0     Admiral  https://acnhcdn.com/latest/NpcIcon/brd06.png
# 1     Agent S  https://acnhcdn.com/latest/NpcIcon/squ05.png
# 2       Agnes  https://acnhcdn.com/latest/NpcIcon/pig17.png
# 3          Al  https://acnhcdn.com/latest/NpcIcon/gor08.png
# 4     Alfonso  https://acnhcdn.com/latest/NpcIcon/crd00.png
# ..        ...                                           ...
# 386    Winnie  https://acnhcdn.com/latest/NpcIcon/hrs05.png
# 387  Wolfgang  https://acnhcdn.com/latest/NpcIcon/wol02.png
# 388      Yuka  https://acnhcdn.com/latest/NpcIcon/kal00.png
# 389      Zell  https://acnhcdn.com/latest/NpcIcon/der02.png
# 390    Zucker  https://acnhcdn.com/latest/NpcIcon/ocp02.png
#
#                                            Photo Image  \
# 0    https://acnhcdn.com/latest/NpcBromide/NpcNmlBr...
# 1    https://acnhcdn.com/latest/NpcBromide/NpcNmlSq...
# 2    https://acnhcdn.com/latest/NpcBromide/NpcNmlPi...
# ...

# %%
categoricas_vecinos.columns
# Out:
# Index(['Name', 'Icon Image', 'Photo Image', 'House Image', 'Species', 'Gender',
#        'Personality', 'Subtype', 'Hobby', 'Birthday', 'Catchphrase',
#        'Favorite Song', 'Favorite Saying', 'Style 1', 'Style 2', 'Color 1',
#        'Color 2', 'Wallpaper', 'Flooring', 'Furniture List',
#        'Furniture Name List', 'Filename', 'Unique Entry ID'],
#       dtype='object')

# %%
categoricas_vecinos.drop(['Icon Image', 'Photo Image', 'House Image', 'Wallpaper', 'Flooring',
       'Furniture List', 'Furniture Name List', 'Filename', 'Unique Entry ID'], axis=1, inplace=True)

# %%
categoricas_vecinos.columns
# Out:
# Index(['Name', 'Species', 'Gender', 'Personality', 'Subtype', 'Hobby',
#        'Birthday', 'Catchphrase', 'Favorite Song', 'Favorite Saying',
#        'Style 1', 'Style 2', 'Color 1', 'Color 2'],
#       dtype='object')

# %%
df_personajes = categoricas_vecinos[['Name', 'Species', 'Gender', 'Personality', 'Subtype', 'Hobby','Birthday',
       'Style 1', 'Style 2', 'Color 1', 'Color 2']].copy()

# %%
df_personajes.columns
# Out:
# Index(['Name', 'Species', 'Gender', 'Personality', 'Subtype', 'Hobby',
#        'Birthday', 'Style 1', 'Style 2', 'Color 1', 'Color 2'],
#       dtype='object')

# %%
df_personajes.head(2)
# Out:
#       Name   Species  Gender Personality Subtype    Hobby Birthday Style 1  \
# 0  Admiral      Bird    Male      Cranky       A   Nature     1/27    Cool
# 1  Agent S  Squirrel  Female       Peppy       B  Fitness      7/2  Active
#
#   Style 2 Color 1 Color 2
# 0    Cool   Black    Blue
# 1  Simple    Blue   Black

# %%
lista_sin_nombres = ['Species', 'Gender', 'Personality', 'Subtype', 'Hobby',
       'Birthday', 'Style 1', 'Style 2', 'Color 1', 'Color 2']

for x in lista_sin_nombres:
    print(f"Los valores únicos de {x.upper()} son: \n {df_personajes[x].unique()}")
# Out:
# Los valores únicos de SPECIES son:
#  ['Bird' 'Squirrel' 'Pig' 'Gorilla' 'Alligator' 'Koala' 'Eagle' 'Anteater'
#  'Bull' 'Mouse' 'Cat' 'Horse' 'Hamster' 'Kangaroo' 'Wolf' 'Penguin'
#  'Chicken' 'Elephant' 'Sheep' 'Deer' 'Tiger' 'Cub' 'Dog' 'Bear' 'Hippo'
#  'Duck' 'Goat' 'Ostrich' 'Rabbit' 'Lion' 'Frog' 'Monkey' 'Rhino' 'Octopus'
#  'Cow']
# Los valores únicos de GENDER son:
#  ['Male' 'Female']
# Los valores únicos de PERSONALITY son:
#  ['Cranky' 'Peppy' 'Big Sister' 'Lazy' 'Normal' 'Snooty' 'Jock' 'Smug']
# Los valores únicos de SUBTYPE son:
#  ['A' 'B']
# Los valores únicos de HOBBY son:
#  ['Nature' 'Fitness' 'Play' 'Education' 'Fashion' 'Music']
# Los valores únicos de BIRTHDAY son:
#  ['1/27' '7/2' '4/21' '10/18' '6/9' '8/19' '11/8' '11/19' '2/16' '3/4'
#  '4/30' '2/24' '9/22' '2/6' '12/2' '10/20' '7/4' '9/24' '9/8' '8/31'
#  '4/28' '2/22' '3/23' '3/28' '11/7' '8/27' '3/2' '10/15' '9/27' '4/5'
#  '12/9' '12/28' '10/10' '8/3' '4/25' '6/12' '12/13' '3/29' '10/3' '2/1'
# ...

# %% [markdown]
# #### Depuración de la columna de cumpleaños para pasarla a datetime:

# %%
#reemplazamos las barras por guiones
df_personajes['Birthday'] = df_personajes['Birthday'].str.replace("/", "-")
df_personajes['Birthday']
# Out:
# 0       1-27
# 1        7-2
# 2       4-21
# 3      10-18
# 4        6-9
#        ...
# 386     1-31
# 387    11-25
# 388     7-20
# 389      6-7
# 390      3-8
# Name: Birthday, Length: 391, dtype: object

# %%
df_personajes.dtypes
# Out:
# Name           object
# Species        object
# Gender         object
# Personality    object
# Subtype        object
# Hobby          object
# Birthday       object
# Style 1        object
# Style 2        object
# Color 1        object
# Color 2        object
# dtype: object

# %% [markdown]
# #### *(Imposible pasarlo a datetime sin que explicite un año, sale 1900).*

# %%
df_personajes.head(2)
# Out:
#       Name   Species  Gender Personality Subtype    Hobby Birthday Style 1  \
# 0  Admiral      Bird    Male      Cranky       A   Nature     1-27    Cool
# 1  Agent S  Squirrel  Female       Peppy       B  Fitness      7-2  Active
#
#   Style 2 Color 1 Color 2
# 0    Cool   Black    Blue
# 1  Simple    Blue   Black

# %%
df_personajes.to_csv('vecines.csv')

# %% [markdown]
# #### Insectos Animal Crossing:

# %%
insectos = pd.read_csv('datos/insects.csv')

# %%
insectos.head(2)
# Out:
#     _id              Name                                     Icon Image  \
# 0  10.0  agrias butterfly   https://acnhcdn.com/latest/MenuIcon/Ins6.png
# 1  69.0               ant  https://acnhcdn.com/latest/MenuIcon/Ins26.png
#
#                                   Critterpedia Image  \
# 0  https://acnhcdn.com/latest/BookInsectIcon/Inse...
# 1  https://acnhcdn.com/latest/BookInsectIcon/Inse...
#
#                                      Furniture Image    Sell  \
# 0  https://acnhcdn.com/latest/FtrIcon/FtrInsectMi...  3000.0
# 1  https://acnhcdn.com/latest/FtrIcon/FtrInsectAr...    80.0
#
#              Where/How          Weather  Total Catches to Unlock Spawn Rates  \
# 0  Flying near flowers  Any except rain                     20.0           5
# 1    On rotten turnips      Any weather                      0.0           0
#
#    ...                                       Catch phrase HHA Base Points  \
# 0  ...  I caught an agrias butterfly! I wonder if it f...            64.0
# ...

# %%
insectos.columns
# Out:
# Index(['_id', 'Name', 'Icon Image', 'Critterpedia Image', 'Furniture Image',
#        'Sell', 'Where/How', 'Weather', 'Total Catches to Unlock',
#        'Spawn Rates', 'NH Jan', 'NH Feb', 'NH Mar', 'NH Apr', 'NH May',
#        'NH Jun', 'NH Jul', 'NH Aug', 'NH Sep', 'NH Oct', 'NH Nov', 'NH Dec',
#        'SH Jan', 'SH Feb', 'SH Mar', 'SH Apr', 'SH May', 'SH Jun', 'SH Jul',
#        'SH Aug', 'SH Sep', 'SH Oct', 'SH Nov', 'SH Dec', 'Size', 'Surface',
#        'Description', 'Catch phrase', 'HHA Base Points', 'HHA Category',
#        'Color 1', 'Color 2', 'Icon Filename', 'Critterpedia Filename',
#        'Furniture Filename', 'Internal ID', 'Unique Entry ID'],
#       dtype='object')

# %%
insectos.drop(['Icon Image', '_id', 'Critterpedia Image', 'Furniture Image', 'NH Apr', 'NH Jan', 'NH Feb', 'NH Mar', 'NH May', 'NH Jun', 'NH Jul', 'NH Aug', 'NH Sep', 'NH Oct',
       'NH Nov', 'NH Dec', 'SH Jan', 'SH Feb', 'SH Mar', 'SH Apr', 'SH May', 'Critterpedia Filename', 'Furniture Filename', 'Icon Filename',
       'SH Jun', 'SH Jul', 'SH Aug', 'SH Sep', 'SH Oct', 'SH Nov', 'SH Dec', 'Unique Entry ID'], axis=1, inplace=True)

# %%
insectos.head(2)
# Out:
#                Name    Sell            Where/How          Weather  \
# 0  agrias butterfly  3000.0  Flying near flowers  Any except rain
# 1               ant    80.0    On rotten turnips      Any weather
#
#    Total Catches to Unlock Spawn Rates Size Surface  \
# 0                     20.0           5  1x1     Yes
# 1                      0.0           0  1x1      No
#
#                                          Description  \
# 0  Some say the agrias butterfly is one of the mo...
# 1  I warn you, the ant may be a small bug, but it...
#
#                                         Catch phrase  HHA Base Points  \
# 0  I caught an agrias butterfly! I wonder if it f...             64.0
# 1       I caught an ant! TELL ME WHERE THE QUEEN IS!             64.0
#
#   HHA Category Color 1 Color 2  Internal ID
# 0          Pet    Pink   Green        620.0
# 1          Pet   Black   White        588.0

# %%
insectos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     80 non-null     object
#  1   Sell                     80 non-null     float64
#  2   Where/How                80 non-null     object
#  3   Weather                  80 non-null     object
#  4   Total Catches to Unlock  80 non-null     float64
#  5   Spawn Rates              80 non-null     object
#  6   Size                     80 non-null     object
#  7   Surface                  80 non-null     object
#  8   Description              80 non-null     object
#  9   Catch phrase             80 non-null     object
#  10  HHA Base Points          80 non-null     float64
#  11  HHA Category             80 non-null     object
#  12  Color 1                  80 non-null     object
#  13  Color 2                  80 non-null     object
# ...

# %%
round(insectos.describe().T, 2)
# Out:
#                          count    mean      std    min     25%    50%  \
# Sell                      80.0  2220.5  3209.39   10.0  237.50  600.0
# Total Catches to Unlock   80.0    17.5    30.08    0.0    0.00    0.0
# HHA Base Points           80.0    64.0     0.00   64.0   64.00   64.0
# Internal ID               80.0  1056.0  1132.81  582.0  603.75  623.5
#
#                              75%      max
# Sell                     2625.00  12000.0
# Total Catches to Unlock    20.00    100.0
# HHA Base Points            64.00     64.0
# Internal ID               644.25   5339.0

# %%
insectos.corr()
# Out:
#                              Sell  Total Catches to Unlock  HHA Base Points  \
# Sell                     1.000000                 0.821856              NaN
# Total Catches to Unlock  0.821856                 1.000000              NaN
# HHA Base Points               NaN                      NaN              NaN
# Internal ID              0.009409                 0.081146              NaN
#
#                          Internal ID
# Sell                        0.009409
# Total Catches to Unlock     0.081146
# HHA Base Points                  NaN
# Internal ID                 1.000000

# %% [markdown]
# # Lista de csv:
#
# ## descartados:
# - accessories
# - achievements
# - bags
# - art
# - fossils
#
# ## interesantes

# %% [markdown]
# #### - **Sea creatures**

# %%
sea_creatures = pd.read_csv('datos/sea creatures.csv')
sea_creatures.head()
# Out:
#     _id                Name  \
# 0  17.0             abalone
# 1  28.0      acorn barnacle
# 2  19.0  chambered nautilus
# 3  25.0      Dungeness crab
# 4  23.0       firefly squid
#
#                                           Icon Image  \
# 0      https://acnhcdn.com/latest/MenuIcon/Awabi.png
# 1  https://acnhcdn.com/latest/MenuIcon/Fujitsubo.png
# 2    https://acnhcdn.com/latest/MenuIcon/Oumugai.png
# 3  https://acnhcdn.com/latest/MenuIcon/DungenessC...
# 4  https://acnhcdn.com/latest/MenuIcon/Hotaruika.png
#
#                                   Critterpedia Image  \
# 0  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 1  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 2  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 3  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 4  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
#
#                                      Furniture Image    Sell   Shadow  \
# ...

# %%
sea_creatures.columns
# Out:
# Index(['_id', 'Name', 'Icon Image', 'Critterpedia Image', 'Furniture Image',
#        'Sell', 'Shadow', 'Movement Speed', 'Total Catches to Unlock',
#        'Spawn Rates', 'NH Jan', 'NH Feb', 'NH Mar', 'NH Apr', 'NH May',
#        'NH Jun', 'NH Jul', 'NH Aug', 'NH Sep', 'NH Oct', 'NH Nov', 'NH Dec',
#        'SH Jan', 'SH Feb', 'SH Mar', 'SH Apr', 'SH May', 'SH Jun', 'SH Jul',
#        'SH Aug', 'SH Sep', 'SH Oct', 'SH Nov', 'SH Dec', 'Size', 'Surface',
#        'Description', 'Catch phrase', 'HHA Base Points', 'HHA Category',
#        'Color 1', 'Color 2', 'Lighting Type', 'Icon Filename',
#        'Critterpedia Filename', 'Furniture Filename', 'Version Added',
#        'Version Unlocked', 'Internal ID', 'Unique Entry ID'],
#       dtype='object')

# %%
fish = pd.read_csv('datos/fish.csv')
fish.head()
# Out:
#     _id             Name                                      Icon Image  \
# 0  56.0          anchovy  https://acnhcdn.com/latest/MenuIcon/Fish81.png
# 1  36.0        angelfish  https://acnhcdn.com/latest/MenuIcon/Fish30.png
# 2  44.0         arapaima  https://acnhcdn.com/latest/MenuIcon/Fish36.png
# 3  41.0          arowana  https://acnhcdn.com/latest/MenuIcon/Fish33.png
# 4  58.0  barred knifejaw  https://acnhcdn.com/latest/MenuIcon/Fish47.png
#
#                                   Critterpedia Image  \
# 0  https://acnhcdn.com/latest/BookFishIcon/FishAn...
# 1  https://acnhcdn.com/latest/BookFishIcon/FishAn...
# 2  https://acnhcdn.com/latest/BookFishIcon/FishPi...
# 3  https://acnhcdn.com/latest/BookFishIcon/FishAr...
# 4  https://acnhcdn.com/latest/BookFishIcon/FishIs...
#
#                                      Furniture Image     Sell Where/How  \
# 0  https://acnhcdn.com/latest/FtrIcon/FtrFishAnty...    200.0       Sea
# ...

# %%
fish['Where/How'].value_counts()
# Out:
# Sea                 29
# River               27
# Pond                12
# Pier                 4
# River (clifftop)     4
# River (mouth)        3
# Sea (rainy days)     1
# Name: Where/How, dtype: int64

# %%
fish.columns.intersection(sea_creatures.columns)
# Out:
# Index(['_id', 'Name', 'Icon Image', 'Critterpedia Image', 'Furniture Image',
#        'Sell', 'Shadow', 'Total Catches to Unlock', 'Spawn Rates', 'NH Jan',
#        'NH Feb', 'NH Mar', 'NH Apr', 'NH May', 'NH Jun', 'NH Jul', 'NH Aug',
#        'NH Sep', 'NH Oct', 'NH Nov', 'NH Dec', 'SH Jan', 'SH Feb', 'SH Mar',
#        'SH Apr', 'SH May', 'SH Jun', 'SH Jul', 'SH Aug', 'SH Sep', 'SH Oct',
#        'SH Nov', 'SH Dec', 'Size', 'Surface', 'Description', 'Catch phrase',
#        'HHA Base Points', 'HHA Category', 'Color 1', 'Color 2',
#        'Lighting Type', 'Icon Filename', 'Critterpedia Filename',
#        'Furniture Filename', 'Internal ID', 'Unique Entry ID'],
#       dtype='object')

# %% [markdown]
# Vemos que tras concatenar los df de peces y criaturas marinas, criaturas marinas no tiene la columna de 'Where/How'. Como son criaturas marinas, reemplazamos estos valores nulos por 'Mar', y fusionamos los valores que contengan 'River' en una sola categoría.

# %% [markdown]
# #### *Concatemos con inner y ya no tenemos nulos <3*

# %%
df_marino_right = pd.concat([sea_creatures, fish], axis = 0, join = 'outer')
df_marino_right.head()
# Out:
#     _id                Name  \
# 0  17.0             abalone
# 1  28.0      acorn barnacle
# 2  19.0  chambered nautilus
# 3  25.0      Dungeness crab
# 4  23.0       firefly squid
#
#                                           Icon Image  \
# 0      https://acnhcdn.com/latest/MenuIcon/Awabi.png
# 1  https://acnhcdn.com/latest/MenuIcon/Fujitsubo.png
# 2    https://acnhcdn.com/latest/MenuIcon/Oumugai.png
# 3  https://acnhcdn.com/latest/MenuIcon/DungenessC...
# 4  https://acnhcdn.com/latest/MenuIcon/Hotaruika.png
#
#                                   Critterpedia Image  \
# 0  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 1  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 2  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 3  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 4  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
#
#                                      Furniture Image    Sell   Shadow  \
# ...

# %%
df_marino_right.drop(['Icon Image', 'Critterpedia Image', 'Furniture Image', 'NH Jan', 'NH Feb', 'NH Mar', 'NH Apr', 'NH May',
       'NH Jun', 'NH Jul', 'NH Aug', 'NH Sep', 'NH Oct', 'NH Nov', 'NH Dec', 'Icon Filename',
       'SH Jan', 'SH Feb', 'SH Mar', 'SH Apr', 'SH May', 'SH Jun', 'SH Jul',
       'SH Aug', 'SH Sep', 'SH Oct', 'SH Nov', 'SH Dec', 'Critterpedia Filename', 'Furniture Filename', 'Internal ID', 'Unique Entry ID',], axis=1, inplace=True)

# %%
df_marino_right.sample(5)
# Out:
#      _id                  Name    Sell   Shadow Movement Speed  \
# 13   5.0                  carp   300.0    Large            NaN
# 15  28.0                  char  3800.0   Medium            NaN
# 1   28.0        acorn barnacle   600.0  X-Small     Stationary
# 28  19.0       giant snakehead  5500.0    Large            NaN
# 38  40.0  Venus' flower basket  5000.0   Medium           Fast
#
#     Total Catches to Unlock Spawn Rates Size Surface  \
# 13                      0.0         3–9  1x1     Yes
# 15                     20.0         1–4  1x1     Yes
# 1                       0.0        6–11  1x1     Yes
# 28                     50.0           2  2x1     Yes
# 38                     40.0         1–3  1x1     Yes
#
#                                           Description  ... HHA Base Points  \
# 13  Oh, the carp... have you ever seen their teeth...  ...            71.0
# 15  The char is one of the bigger first around the...  ...            71.0
# ...

# %%
df_marino_right["Where/How"] = df_marino_right["Where/How"].replace(np.nan, "Sea")

# %%
numericas = df_marino_right.select_dtypes(include=np.number)

for x in numericas:
    df_marino_right[x] = df_marino_right[x].astype(int)

# %%
df_marino = pd.concat([sea_creatures, fish], axis = 0, join = 'inner')
df_marino.head()
# Out:
#     _id                Name  \
# 0  17.0             abalone
# 1  28.0      acorn barnacle
# 2  19.0  chambered nautilus
# 3  25.0      Dungeness crab
# 4  23.0       firefly squid
#
#                                           Icon Image  \
# 0      https://acnhcdn.com/latest/MenuIcon/Awabi.png
# 1  https://acnhcdn.com/latest/MenuIcon/Fujitsubo.png
# 2    https://acnhcdn.com/latest/MenuIcon/Oumugai.png
# 3  https://acnhcdn.com/latest/MenuIcon/DungenessC...
# 4  https://acnhcdn.com/latest/MenuIcon/Hotaruika.png
#
#                                   Critterpedia Image  \
# 0  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 1  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 2  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 3  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
# 4  https://acnhcdn.com/latest/BookDiveFishIcon/Di...
#
#                                      Furniture Image    Sell   Shadow  \
# ...

# %%
df_marino.isnull().sum()
# Out:
# _id                         0
# Name                        0
# Icon Image                  0
# Critterpedia Image          0
# Furniture Image             0
# Sell                        0
# Shadow                      0
# Total Catches to Unlock     0
# Spawn Rates                 0
# NH Jan                     69
# NH Feb                     71
# NH Mar                     66
# NH Apr                     61
# NH May                     54
# NH Jun                     41
# NH Jul                     38
# NH Aug                     36
# NH Sep                     30
# NH Oct                     56
# NH Nov                     58
# NH Dec                     65
# SH Jan                     38
# SH Feb                     36
# SH Mar                     30
# SH Apr                     56
# SH May                     58
# SH Jun                     65
# SH Jul                     69
# SH Aug                     71
# SH Sep                     66
# SH Oct                     61
# ...

# %%
df_marino.columns
# Out:
# Index(['_id', 'Name', 'Icon Image', 'Critterpedia Image', 'Furniture Image',
#        'Sell', 'Shadow', 'Total Catches to Unlock', 'Spawn Rates', 'NH Jan',
#        'NH Feb', 'NH Mar', 'NH Apr', 'NH May', 'NH Jun', 'NH Jul', 'NH Aug',
#        'NH Sep', 'NH Oct', 'NH Nov', 'NH Dec', 'SH Jan', 'SH Feb', 'SH Mar',
#        'SH Apr', 'SH May', 'SH Jun', 'SH Jul', 'SH Aug', 'SH Sep', 'SH Oct',
#        'SH Nov', 'SH Dec', 'Size', 'Surface', 'Description', 'Catch phrase',
#        'HHA Base Points', 'HHA Category', 'Color 1', 'Color 2',
#        'Lighting Type', 'Icon Filename', 'Critterpedia Filename',
#        'Furniture Filename', 'Internal ID', 'Unique Entry ID'],
#       dtype='object')

# %%
df_marino.drop(['Icon Image', 'Critterpedia Image', 'Furniture Image', 'NH Jan', 'NH Feb', 'NH Mar', 'NH Apr', 'NH May',
       'NH Jun', 'NH Jul', 'NH Aug', 'NH Sep', 'NH Oct', 'NH Nov', 'NH Dec', 'Icon Filename',
       'SH Jan', 'SH Feb', 'SH Mar', 'SH Apr', 'SH May', 'SH Jun', 'SH Jul',
       'SH Aug', 'SH Sep', 'SH Oct', 'SH Nov', 'SH Dec', 'Critterpedia Filename', 'Furniture Filename', 'Internal ID', 'Unique Entry ID',], axis=1, inplace=True)

# %%
df_marino.isnull().sum()
# Out:
# _id                        0
# Name                       0
# Sell                       0
# Shadow                     0
# Total Catches to Unlock    0
# Spawn Rates                0
# Size                       0
# Surface                    0
# Description                0
# Catch phrase               0
# HHA Base Points            0
# HHA Category               0
# Color 1                    0
# Color 2                    0
# Lighting Type              0
# dtype: int64

# %%
df_marino.shape
# Out:
# (120, 15)

# %%
df_marino.sample(5)
# Out:
#      _id           Name    Sell   Shadow  Total Catches to Unlock Spawn Rates  \
# 0   56.0        anchovy   200.0    Small                      0.0         2–5
# 6   37.0          betta  2500.0    Small                     20.0         1–4
# 72  50.0    surgeonfish  1000.0    Small                      0.0           2
# 45  35.0    nibble fish  1500.0  X-Small                     20.0           2
# 11  32.0  mantis shrimp  2500.0    Small                     20.0         2–8
#
#    Size Surface                                        Description  \
# 0   1x1      No  There are more than 140 species of anchovy, bu...
# 6   1x1      No  The betta has long fins and beautiful coloring...
# 72  1x1      No  Hoo! Careful, now! These fish are particularly...
# 45  1x1      No  Nibble fish are best known for their use in a ...
# 11  1x1     Yes  Think carefully before you mock the mantis shr...
#
#                                          Catch phrase  HHA Base Points  \
# ...

# %%
df_marino["Lighting Type"].unique()
# Out:
# array(['Fluorescent', 'No lighting', 'Emission'], dtype=object)

# %% [markdown]
# #### **Categorización animales**

# %%
df_personajes.head(2)
# Out:
#       Name   Species  Gender Personality Subtype    Hobby Birthday Style 1  \
# 0  Admiral      Bird    Male      Cranky       A   Nature     1-27    Cool
# 1  Agent S  Squirrel  Female       Peppy       B  Fitness      7-2  Active
#
#   Style 2 Color 1 Color 2
# 0    Cool   Black    Blue
# 1  Simple    Blue   Black

# %%
df_personajes["Type"] = df_personajes["Species"]

# %%
df_personajes.head()
# Out:
#       Name    Species  Gender Personality Subtype    Hobby Birthday Style 1  \
# 0  Admiral       Bird    Male      Cranky       A   Nature     1-27    Cool
# 1  Agent S   Squirrel  Female       Peppy       B  Fitness      7-2  Active
# 2    Agnes        Pig  Female  Big Sister       A     Play     4-21  Simple
# 3       Al    Gorilla    Male        Lazy       B  Fitness    10-18  Active
# 4  Alfonso  Alligator    Male        Lazy       B     Play      6-9  Simple
#
#    Style 2 Color 1 Color 2       Type
# 0     Cool   Black    Blue       Bird
# 1   Simple    Blue   Black   Squirrel
# 2  Elegant    Pink   White        Pig
# 3   Active     Red   White    Gorilla
# 4   Simple     Red    Blue  Alligator

# %%
df_personajes['Birthday'] = pd.to_datetime(df_personajes['Birthday'], format='2023-%m-%d')

# %%
df_personajes.dtypes
# Out:
# Name                   object
# Species                object
# Gender                 object
# Personality            object
# Subtype                object
# Hobby                  object
# Birthday       datetime64[ns]
# Style 1                object
# Style 2                object
# Color 1                object
# Color 2                object
# Type                   object
# dtype: object

# %%
df_personajes.head()
# Out:
#       Name    Species  Gender Personality Subtype    Hobby   Birthday Style 1  \
# 0  Admiral       Bird    Male      Cranky       A   Nature 1900-01-27    Cool
# 1  Agent S   Squirrel  Female       Peppy       B  Fitness 1900-07-02  Active
# 2    Agnes        Pig  Female  Big Sister       A     Play 1900-04-21  Simple
# 3       Al    Gorilla    Male        Lazy       B  Fitness 1900-10-18  Active
# 4  Alfonso  Alligator    Male        Lazy       B     Play 1900-06-09  Simple
#
#    Style 2 Color 1 Color 2       Type
# 0     Cool   Black    Blue       Bird
# 1   Simple    Blue   Black     Mammal
# 2  Elegant    Pink   White     Mammal
# 3   Active     Red   White     Mammal
# 4   Simple     Red    Blue  Amphibian

# %% [markdown]
# mammal, amphibian, bird,

# %%
df_personajes["Species"].unique()
# Out:
# array(['Bird', 'Squirrel', 'Pig', 'Gorilla', 'Alligator', 'Koala',
#        'Eagle', 'Anteater', 'Bull', 'Mouse', 'Cat', 'Horse', 'Hamster',
#        'Kangaroo', 'Wolf', 'Penguin', 'Chicken', 'Elephant', 'Sheep',
#        'Deer', 'Tiger', 'Cub', 'Dog', 'Bear', 'Hippo', 'Duck', 'Goat',
#        'Ostrich', 'Rabbit', 'Lion', 'Frog', 'Monkey', 'Rhino', 'Octopus',
#        'Cow'], dtype=object)

# %%
df_personajes["Type"].replace("Squirrel", "Mammal")
# Out:
# 0           Bird
# 1         Mammal
# 2            Pig
# 3        Gorilla
# 4      Alligator
#          ...
# 386        Horse
# 387         Wolf
# 388        Koala
# 389         Deer
# 390      Octopus
# Name: Type, Length: 391, dtype: object

# %%
df_personajes.head()
# Out:
#       Name    Species  Gender Personality Subtype    Hobby   Birthday Style 1  \
# 0  Admiral       Bird    Male      Cranky       A   Nature 1900-01-27    Cool
# 1  Agent S   Squirrel  Female       Peppy       B  Fitness 1900-07-02  Active
# 2    Agnes        Pig  Female  Big Sister       A     Play 1900-04-21  Simple
# 3       Al    Gorilla    Male        Lazy       B  Fitness 1900-10-18  Active
# 4  Alfonso  Alligator    Male        Lazy       B     Play 1900-06-09  Simple
#
#    Style 2 Color 1 Color 2       Type
# 0     Cool   Black    Blue       Bird
# 1   Simple    Blue   Black   Squirrel
# 2  Elegant    Pink   White        Pig
# 3   Active     Red   White    Gorilla
# 4   Simple     Red    Blue  Alligator

# %%
def tipo(col):
    
    mammals = ['Squirrel', 'Pig', 'Gorilla', 'Koala', 'Anteater', 'Bull', 'Mouse', 'Cat', 'Horse', 'Hamster',
        'Kangaroo', 'Wolf', 'Elephant', 'Sheep', 'Deer', 'Tiger', 'Cub', 'Dog', 'Bear', 'Hippo', 'Goat',
        'Rabbit', 'Lion', 'Monkey', 'Rhino', 'Cow']

    birds = ['Bird', 'Eagle', 'Penguin', 'Chicken', 'Duck', 'Ostrich']

    amphibians = ['Alligator', 'Frog', 'Octopus']

    if col in mammals:
        return "Mammal"
    elif col in birds:
        return "Bird"
    elif col in amphibians:
        return "Amphibian"
    else:
        pass

# %%
df_personajes["Type"] = df_personajes["Type"].apply(tipo)

# %%
df_personajes.head()
# Out:
#       Name    Species  Gender Personality Subtype    Hobby   Birthday Style 1  \
# 0  Admiral       Bird    Male      Cranky       A   Nature 1900-01-27    Cool
# 1  Agent S   Squirrel  Female       Peppy       B  Fitness 1900-07-02  Active
# 2    Agnes        Pig  Female  Big Sister       A     Play 1900-04-21  Simple
# 3       Al    Gorilla    Male        Lazy       B  Fitness 1900-10-18  Active
# 4  Alfonso  Alligator    Male        Lazy       B     Play 1900-06-09  Simple
#
#    Style 2 Color 1 Color 2       Type
# 0     Cool   Black    Blue       Bird
# 1   Simple    Blue   Black     Mammal
# 2  Elegant    Pink   White     Mammal
# 3   Active     Red   White     Mammal
# 4   Simple     Red    Blue  Amphibian

# %%
df_personajes.to_csv("vecines_tipo.csv")

# %% [markdown]
# #### Categorizar insectos

# %%
insectos.head()
# Out:
#                Name    Sell                               Where/How  \
# 0  agrias butterfly  3000.0                     Flying near flowers
# 1               ant    80.0                       On rotten turnips
# 2        Atlas moth  3000.0                     On trees (any kind)
# 3           bagworm   600.0  Shaking trees (hardwood or cedar only)
# 4  banded dragonfly  4500.0                       Flying near water
#
#            Weather  Total Catches to Unlock Spawn Rates Size Surface  \
# 0  Any except rain                     20.0           5  1x1     Yes
# 1      Any weather                      0.0           0  1x1      No
# 2      Any weather                     20.0           5  1x1     Yes
# 3      Any weather                      0.0          50  1x1     Yes
# 4  Any except rain                     50.0           7  1x1     Yes
#
#                                          Description  \
# 0  Some say the agrias butterfly is one of the mo...
# ...

# %%
insectos["Where/How"].unique()
# Out:
# array(['Flying near flowers', 'On rotten turnips', 'On trees (any kind)',
#        'Shaking trees (hardwood or cedar only)', 'Flying near water',
#        'On the ground', 'On palm trees', 'On hardwood/cedar trees',
#        'From hitting rocks', 'On tree stumps', 'Flying',
#        'On rivers/ponds', 'Pushing snowballs', 'On villagers',
#        'Flying near trash (boots, tires, cans) or rotten turnips',
#        'Disguised on shoreline', 'On flowers',
#        'Underground (dig where noise is loudest)',
#        'Flying near light sources', 'On white flowers',
#        'Flying near blue/purple/black flowers', 'On rocks/bushes',
#        'Disguised under trees', 'Shaking trees', 'On beach rocks'],
#       dtype=object)

# %%
def dondebixos(col):
    
    near_flowers = ['Flying near flowers', 'On flowers', 'On white flowers', 'Flying near blue/purple/black flowers']

    near_forest = ['On trees (any kind)', 'Shaking trees (hardwood or cedar only)', 'On hardwood/cedar trees',
    'On tree stumps', 'Disguised under trees', 'Shaking trees']

    near_ground = ['On the ground', 'From hitting rocks', 'On tree stumps','Pushing snowballs',
        'Disguised on shoreline', 'On flowers', 'Flying',
        'Underground (dig where noise is loudest)', 'On rocks/bushes','On beach rocks']

    near_capitalism = ['On rotten turnips', 'On villagers', 'Flying near light sources',
    'Flying near trash (boots, tires, cans) or rotten turnips']

    near_water = ['Flying near water', 'On palm trees', 'On rivers/ponds', 'Disguised on shoreline', 'On beach rocks']

    if col in near_flowers:
        return "Near flowers"
    elif col in near_forest:
        return "Near forest"
    elif col in near_ground:
        return "Near ground"
    elif col in near_capitalism:
        return "Near town"
    elif col in near_water:
        return "Near water"

# %%
near_flowers = ['Flying near flowers', 'On flowers', 'On white flowers', 'Flying near blue/purple/black flowers']

near_forest = ['On trees (any kind)', 'Shaking trees (hardwood or cedar only)', 'On hardwood/cedar trees',
'On tree stumps', 'Disguised under trees', 'Shaking trees']

near_ground = ['On the ground', 'From hitting rocks', 'On tree stumps','Pushing snowballs',
    'Disguised on shoreline', 'On flowers', 'Flying',
    'Underground (dig where noise is loudest)', 'On rocks/bushes', 'On beach rocks']

near_capitalism = ['On rotten turnips', 'On villagers', 'Flying near light sources', 
'Flying near trash (boots, tires, cans) or rotten turnips']

near_water = ['Flying near water', 'On palm trees', 'On rivers/ponds', 'Disguised on shoreline', 'On beach rocks']

# %%
lista_todo = near_flowers + near_forest + near_ground + near_capitalism + near_water

# %%
lista_todito = ['Flying near flowers', 'On rotten turnips', 'On trees (any kind)',
       'Shaking trees (hardwood or cedar only)', 'Flying near water',
       'On the ground', 'On palm trees', 'On hardwood/cedar trees',
       'From hitting rocks', 'On tree stumps', 'Flying',
       'On rivers/ponds', 'Pushing snowballs', 'On villagers',
       'Flying near trash (boots, tires, cans) or rotten turnips',
       'Disguised on shoreline', 'On flowers',
       'Underground (dig where noise is loudest)',
       'Flying near light sources', 'On white flowers',
       'Flying near blue/purple/black flowers', 'On rocks/bushes',
       'Disguised under trees', 'Shaking trees', 'On beach rocks']

# %%
lista_todo == lista_todito
# Out:
# False

# %%
list(set(lista_todo).symmetric_difference(set(lista_todito)))
# Out:
# []

# %%
insectos["Whereabouts"] = insectos["Where/How"].apply(dondebixos)

# %%
insectos.head()
# Out:
#                Name    Sell                               Where/How  \
# 0  agrias butterfly  3000.0                     Flying near flowers
# 1               ant    80.0                       On rotten turnips
# 2        Atlas moth  3000.0                     On trees (any kind)
# 3           bagworm   600.0  Shaking trees (hardwood or cedar only)
# 4  banded dragonfly  4500.0                       Flying near water
#
#            Weather  Total Catches to Unlock Spawn Rates Size Surface  \
# 0  Any except rain                     20.0           5  1x1     Yes
# 1      Any weather                      0.0           0  1x1      No
# 2      Any weather                     20.0           5  1x1     Yes
# 3      Any weather                      0.0          50  1x1     Yes
# 4  Any except rain                     50.0           7  1x1     Yes
#
#                                          Description  \
# 0  Some say the agrias butterfly is one of the mo...
# ...

# %%
insectos["Sell"].unique()
# Out:
# array([3.00e+03, 8.00e+01, 6.00e+02, 4.50e+03, 4.30e+02, 8.00e+02,
#        2.50e+02, 3.00e+02, 1.00e+01, 3.50e+02, 1.60e+02, 1.30e+02,
#        8.00e+03, 5.00e+02, 2.30e+02, 2.00e+02, 4.00e+03, 5.50e+02,
#        7.00e+01, 6.00e+01, 1.00e+04, 2.00e+03, 1.20e+04, 1.00e+03,
#        1.35e+03, 2.40e+03, 2.50e+03, 1.40e+02, 6.00e+03, 1.80e+02,
#        4.00e+02, 1.20e+02, 1.50e+03, 2.40e+02, 4.50e+02])

# %%
insectos.mean()
# Out:
# Sell                       2220.5
# Total Catches to Unlock      17.5
# HHA Base Points              64.0
# Internal ID                1056.0
# dtype: float64

# %%
numericas = insectos.select_dtypes(include=np.number)

for x in numericas:
    insectos[x] = insectos[x].astype(int)

# %%
insectos.dtypes
# Out:
# Name                       object
# Sell                        int64
# Where/How                  object
# Weather                    object
# Total Catches to Unlock     int64
# Spawn Rates                object
# Size                       object
# Surface                    object
# Description                object
# Catch phrase               object
# HHA Base Points             int64
# HHA Category               object
# Color 1                    object
# Color 2                    object
# Internal ID                 int64
# Whereabouts                object
# dtype: object

# %%
insectos.head()
# Out:
#                Name  Sell                               Where/How  \
# 0  agrias butterfly  3000                     Flying near flowers
# 1               ant    80                       On rotten turnips
# 2        Atlas moth  3000                     On trees (any kind)
# 3           bagworm   600  Shaking trees (hardwood or cedar only)
# 4  banded dragonfly  4500                       Flying near water
#
#            Weather  Total Catches to Unlock Spawn Rates Size Surface  \
# 0  Any except rain                       20           5  1x1     Yes
# 1      Any weather                        0           0  1x1      No
# 2      Any weather                       20           5  1x1     Yes
# 3      Any weather                        0          50  1x1     Yes
# 4  Any except rain                       50           7  1x1     Yes
#
#                                          Description  \
# 0  Some say the agrias butterfly is one of the mo...
# ...

# %% [markdown]
# Depurar:
# - Limpiar los dfs.

# %%
insectos.isnull().sum()
# Out:
# Name                       0
# Sell                       0
# Where/How                  0
# Weather                    0
# Total Catches to Unlock    0
# Spawn Rates                0
# Size                       0
# Surface                    0
# Description                0
# Catch phrase               0
# HHA Base Points            0
# HHA Category               0
# Color 1                    0
# Color 2                    0
# Internal ID                0
# Whereabouts                0
# dtype: int64

# %%
lista_sin_nombres = ['Name', 'Sell', 'Where/How', 'Weather',
       'Total Catches to Unlock', 'Spawn Rates', 'Size', 'Surface', 'Whereabouts']

for x in lista_sin_nombres:
    print(f"Los valores únicos de {x.upper()} son: \n {insectos[x].unique()}")
    print(f"\n <3    <3    <3    <3    <3 \n")
# Out:
# Los valores únicos de NAME son:
#  ['agrias butterfly' 'ant' 'Atlas moth' 'bagworm' 'banded dragonfly'
#  'bell cricket' 'blue weevil beetle' 'brown cicada' 'centipede'
#  'cicada shell' 'citrus long-horned beetle' 'common bluebottle'
#  'common butterfly' 'cricket' 'cyclommatus stag' 'damselfly'
#  'darner dragonfly' 'diving beetle' 'drone beetle' 'dung beetle'
#  'earth-boring dung beetle' 'emperor butterfly' 'evening cicada' 'firefly'
#  'flea' 'fly' 'giant cicada' 'giant stag' 'giant water bug' 'giraffe stag'
#  'golden stag' 'goliath beetle' 'grasshopper' 'great purple emperor'
#  'hermit crab' 'honeybee' 'horned atlas' 'horned dynastid'
#  'horned elephant' 'horned hercules' 'jewel beetle' 'ladybug'
#  'long locust' 'Madagascan sunset moth' 'man-faced stink bug' 'mantis'
#  'migratory locust' 'miyama stag' 'mole cricket' 'monarch butterfly'
#  'mosquito' 'moth' 'orchid mantis' 'paper kite butterfly'
#  'peacock butterfly' 'pill bug' 'pondskater' "Queen Alexandra's birdwing"
# ...

# %%
insectos["Weather"].unique()
# Out:
# array(['Any except rain', 'Any weather', 'Rain only'], dtype=object)
